# %%
import spotipy as sp
import spotipy.util as util
import pandas as pd
import json
import time

# %%
token = util.prompt_for_user_token(username='u76krgcu2i52isp9ktf2acmmp', 
                           scope='user-library-read',
                           client_id='71f8b6e1b36740a8acda7e15c5e1d73d',
                           client_secret='ebb9411ac7f5455a9cbb752dbb7e4f9f',
                           redirect_uri='https://example.com/callbacks')

# %%
spot= sp.Spotify(auth=token)

# %%
genres = pd.DataFrame(spot.recommendation_genre_seeds())
genres
# Out:
#                 genres
# 0             acoustic
# 1             afrobeat
# 2             alt-rock
# 3          alternative
# 4              ambient
# 5                anime
# 6          black-metal
# 7            bluegrass
# 8                blues
# 9            bossanova
# 10              brazil
# 11           breakbeat
# 12             british
# 13            cantopop
# 14       chicago-house
# 15            children
# 16               chill
# 17           classical
# 18                club
# 19              comedy
# 20             country
# 21               dance
# 22           dancehall
# 23         death-metal
# 24          deep-house
# 25      detroit-techno
# 26               disco
# 27              disney
# 28       drum-and-bass
# 29                 dub
# ..                 ...
# 96              reggae
# 97           reggaeton
# 98           road-trip
# 99                rock
# 100        rock-n-roll
# 101         rockabilly
# 102            romance
# 103                sad
# 104              salsa
# 105              samba
# 106          sertanejo
# 107         show-tunes
# 108  singer-songwriter
# 109                ska
# 110              sleep
# 111         songwriter
# 112               soul
# 113        soundtracks
# 114            spanish
# 115              study
# 116             summer
# 117            swedish
# 118          synth-pop
# 119              tango
# 120             techno
# 121             trance
# 122           trip-hop
# 123            turkish
# 124           work-out
# 125        world-music
#
# [126 rows x 1 columns]

# %%
#for type track . lets try 1 track limit = 1
results_t = spot.search(q='Michael-Jackson',limit=1, type='track')
#print(json.dumps(results,indent=4, ))
artist_id= results_t['tracks']['items'][0]['album']['artists'][0]['id']
artist_name = results_t['tracks']['items'][0]['album']['artists'][0]['name']
artist_uri = results_t['tracks']['items'][0]['album']['artists'][0]['uri']

# %%
results_t['tracks']['items'][0]['name']
# Out:
# 'Billie Jean'

# %%
track_id = results_t['tracks']['items'][0]['id']
track_name = results_t['tracks']['items'][0]['name']

# %%
# for type artist getting artist genre. limit 1
results_a = spot.search(q=artist, limit=1, type='artist' )
results_a
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Basslovers+United&type=artist&market=US&offset=0&limit=1',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KpgeSLtjj0txr6drzaedu'},
#     'followers': {'href': None, 'total': 13837},
#     'genres': ['eurodance', 'hands up', 'pop house'],
#     'href': 'https://api.spotify.com/v1/artists/4KpgeSLtjj0txr6drzaedu',
#     'id': '4KpgeSLtjj0txr6drzaedu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6b87f7afea8928a01ec68205fc6cd81112cf77af',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/2107e939259392abc487e98984b99af980df039e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/3bf8444d07470e633f33f1b5f823c5b106a40979',
#       'width': 160}],
#     'name': 'Basslovers United',
#     'popularity': 47,
#     'type': 'artist',
#     'uri': 'spotify:artist:4KpgeSLtjj0txr6drzaedu'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Basslovers+United&type=artist&market=US&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 3}}

# %%
genres = results_a['artists']['items'][0]['genres']
genres
# Out:
# ['eurodance', 'hands up', 'pop house']

# %%
artist = spot.artist('spotify:artist:4KpgeSLtjj0txr6drzaedu')['name']#use this as artist list, we can start pull.
artist
# Out:
# 'Basslovers United'

# %%
aud_feat = spot.audio_features(track_id)  # look for track id's, think about appending a bunch of track ids to a list
danceability = aud_feat[0]['danceability']
energy = aud_feat[0]['energy']
loudness = aud_feat[0]['loudness']
mode = aud_feat[0]['mode']
speechiness = aud_feat[0]['speechiness']
acousticness = aud_feat[0]['acousticness']
intrumentalness = aud_feat[0]['instrumentalness']
liveness = aud_feat[0]['liveness']
valence = aud_feat[0]['valence']
tempo = aud_feat[0]['tempo']
time_signature = aud_feat[0]['time_signature']

# %%
artist_list = pd.read_csv('./artist-uris.csv.csv', header=None) # great jerb

# %%
artist_list.dropna(axis=0, inplace=True)

# %%
artist_list.isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
artist_list.rename(columns={0:'artist', 1:'id'}, inplace=True)

# %%
artist_list.loc[5555]
# Out:
# artist                        Basslovers United
# id        spotify:artist:4KpgeSLtjj0txr6drzaedu
# Name: 5555, dtype: object

# %%
artist_list.tail()
# Out:
#                       artist                                     id
# 81318                    黃曉明  spotify:artist:53F8atvCmVFVOvnKwZXBd3
# 81319                    黃玠瑋  spotify:artist:6VI0p0xTjBKKxQN8i8vGpD
# 81320                    黃義達  spotify:artist:7kaq0LysuRSgBZSorlZ7Vj
# 81321  黃顯忠 (Huang Xianzhong)  spotify:artist:7MuuEryyseo5cvReO6gdPF
# 81322                #ERROR!  spotify:artist:1easDqNuXyccZdonMosEiU

# %%
results_t = spot.search(q='Michael-Jackson',limit=1, type='track')
results_t
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Michael-Jackson&type=track&market=US&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#        'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#        'id': '3fMbdgg4jU18AjLCKBhRSm',
#        'name': 'Michael Jackson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1C2h7mLntPSeVYciMRTF4a'},
#      'href': 'https://api.spotify.com/v1/albums/1C2h7mLntPSeVYciMRTF4a',
#      'id': '1C2h7mLntPSeVYciMRTF4a',
#      'images': [{'height': 568,
#        'url': 'https://i.scdn.co/image/3c294000d8739af300d9a842934d6f7e090471c7',
#        'width': 640},
#       {'height': 266,
#        'url': 'https://i.scdn.co/image/d50dab8e3338d47ddc84195a0779b6b80704f8c5',
#        'width': 300},
#       {'height': 57,
#        'url': 'https://i.scdn.co/image/eb2b6bb819fd2b1795acd65efc8e1a975c487afc',
#        'width': 64}],
#      'name': 'Thriller 25 Super Deluxe Edition',
#      'release_date': '1982-11-30',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:1C2h7mLntPSeVYciMRTF4a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#       'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#       'id': '3fMbdgg4jU18AjLCKBhRSm',
#       'name': 'Michael Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 293826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19902991'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ChkMS8OtdzJeqyybCc9R5'},
#     'href': 'https://api.spotify.com/v1/tracks/5ChkMS8OtdzJeqyybCc9R5',
#     'id': '5ChkMS8OtdzJeqyybCc9R5',
#     'is_local': False,
#     'name': 'Billie Jean',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4eb779428d40d579f14d12a9daf98fc66c7d0be4?cid=71f8b6e1b36740a8acda7e15c5e1d73d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5ChkMS8OtdzJeqyybCc9R5'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Michael-Jackson&type=track&market=US&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 9107}}

# %%
track_infos = []
for i in artist_list['id']:
    artist_name = spot.artist(i)['name']
    results_t = spot.search(q= artist_name,limit=1, type='track')
    try:
        track_id = results_t['tracks']['items'][0]['id']
    except:
        'list index out of range'
    print(track_id)
# Out:
# 2WfVrIuhnF8xY0nDB3Kkfn
# 1nX9KhK3Fff27SnrIor2Yb
# 1XPAT6kvtcbEyoTogtXyc5
# 44L7aDHaRzb9pMWEZjSH8u
# 2jZPEeW2ynykb2GkVqpOkJ
# 02Io4lJ2wtUAVKlmDA6v4S
# 7yFTB1mdOfiv3BJnBRvVoE
# 0tvcECTsYzitHJdmirb71C
# 0q5t7MYgLsG6uplwdxAltv
# 5SxkdsY1ufZzoq9iXceLw9
# 4QtiVmuA88tPQiCOHZuQ5b
# 7oHkit3F3vimtsBbnZkU0G
# 7i6r9KotUPQg3ozKKgEPIN
# 2KpqZo4eUBkqBU9nlYNANc
# 4QtiVmuA88tPQiCOHZuQ5b
# 2jZPEeW2ynykb2GkVqpOkJ
# 0uBpy6SFhl1oYiAEqzeHQE
# 1IoFeQD7aNY9hfYggbPAiu
# 2YDCZEMZYbETqsIbpEoUpq
# 2EXcwWfYF4DgMMMvYJ1bPg
# 2EXcwWfYF4DgMMMvYJ1bPg
# 2EXcwWfYF4DgMMMvYJ1bPg
# 2EXcwWfYF4DgMMMvYJ1bPg
# 2EXcwWfYF4DgMMMvYJ1bPg
# 7MRrN7Ags7aAqD6z8Opy2H
# 6I2lZcI1Dm8VeUYsOASNxz
# 6I2lZcI1Dm8VeUYsOASNxz
# 3MZ0Obyv6AnO1anmGBJydv
# 05qCCJQJiOwvPQBb7akf1R
# 4htOz9gMFZStfcVz1kx3El
# 4PEeZ2U4UfP2Jo8EtIOjus
# 6kixQpOqh28TiGN0Xm70U9
# 0pSBuHjILhNEo55xK1zrRt
# 2uO57D5iy4YJ9eMcbnlY8y
# 2zbjlcLi1VQWqDNYdhyx1l
# 7BaTqGZEDSj9943y404BUJ
# 2GGkXContcq2SZpXuEAlyf
# 2Qw6jgFXAmCBjTgpu18Nv2
# 5ZRpzj4j5gDSoIbNLagcbB
# 5ZRpzj4j5gDSoIbNLagcbB
# 3i2qvQpEqbcpkyYuHsYBis
# 60R2v9lheAu3lwZwAFxMZK
# 6A9zBqr5sccEHHNqOjYd3S
# 43PuMrRfbyyuz4QpZ3oAwN
# 3RUytXAnGwi02QFkBvRUv3
# 08mG3Y1vljYA6bvDt4Wqkj
# 5yrGsJoG4FsTg6luHlNGK2
# 0ozmdM7J3BQfMlPwAFJiGQ
# 0ozmdM7J3BQfMlPwAFJiGQ
# 3NzLIbvq342cvzDlDH33RV
# 6CALmCM3Qh71iTuiOOl4KC
# 5kDGMyVaApebWfHvP1NP3Q
# 6J1R5wtPXiHiwiPstOSI56
# 1NrDNae8aZulSLdPt36K6e
# 1NrDNae8aZulSLdPt36K6e
# 6vxVcSs2J7TTfdrHxPMztr
# 7IoVZ7yynM2uKQOTR0s0Ua
# 1buMu2LU0jWm0CpX3y6Jub
# 7z9TEL3RiPw1v5UUM35U9v
# 0uf0jjRGQFiFsBcW50ywZt
# 25IcqPUbCUIipmrTcZFRKG
# 3ZM9omzPu7UTxxT3OOQHjI
# 6pWzEnoUsuiTcp6odVDovx
# 7jNQ6fmYZ9QtKIVnRMe6Lq
# 2fRo47QZ5vZHyyrlHeFHej
# 62bOmKYxYg7dhrC6gH9vFn
# 4LFwNJWoj74Yd71fIr1W8x
# 2z3joGXrdGL2iEjIKQTiN1
# 0hzamRAPFezrDRkq61WIdS
# 3pLTOP0G0etiWUknFoRpsr
# 2l33bJRXROBqAXHeHT4Hi4
# 0M7mWKqwTIaVjYyxfZmtTa
# 25E8bGymV8oTPf4vbSM69C
# 5KASWsajPmTEecVWiBsUZW
# 0FRYhpzKAnckScvm3VlovK
# 0FRYhpzKAnckScvm3VlovK
# 7Il2yWQmsqKgSkLQvHTPUI
# 1S4fpfX2u0hzFD9vb6FEB6
# 2UjcMFyEhvunXzblOdWh85
# 0oPKi455b9ejRX7NCrYHju
# 2wg54uCVdrwPCua37mhrCr
# 2EjxMFZkkE6BEoUiSykoGv
# 3fyMH1t6UPeR5croea9PrR
# 0DKau80WuUTgKrJV82r6ZJ
# 3XD48GXmGwLWiQexiJtDbS
# 1wm0lZDhdy5pNOoKKc8S5k
# 32OkBQinMWqa7ZydEkHqVi
# 74hpFi8WyIwFIPBUv0idC3
# 4LmAnpjlhWTahvRkYR8xJa
# 1N1TjFEynnN1OExq1xghno
# 5ZGUzD2WAYXx1P8O7FVQph
# 4fXtpQEh7EMrnWaf1lDpeE
# 5XAPpyIoYF3QXP34Hv8Pvx
# 3njFvQ5RakFdFldXN8uAuj
# 2ezsLpf3lV1TcDAF3RfOYD
# 0RySKi4j0iW5yS116alcba
# 7IS4HZw7zgWE0RntLvTwRD
# 66TqyIw4lqniQu62cbMfyz
# 5fp6m6Zo4LetiWaMMrPjy5
# 0zv07tjR3lHDRzvumLbLl9
# 1R69FDYYnNvNOdigumPi7N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8074026b3cb5> in <module>()
#       2 for i in artist_list['id']:
#       3     artist_name = spot.artist(i)['name']
# ----> 4     results_t = spot.search(q= artist_name,limit=1, type='track')
#       5     try:
#       6         track_id = results_t['tracks']['items'][0]['id']
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %%
results_t = spot.search(q= artist,limit=1, type='track')
results_t
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Basslovers+United&type=track&market=US&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KpgeSLtjj0txr6drzaedu'},
#        'href': 'https://api.spotify.com/v1/artists/4KpgeSLtjj0txr6drzaedu',
#        'id': '4KpgeSLtjj0txr6drzaedu',
#        'name': 'Basslovers United',
#        'type': 'artist',
#        'uri': 'spotify:artist:4KpgeSLtjj0txr6drzaedu'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52zcKFagA0FwPArP7g94sH'},
#      'href': 'https://api.spotify.com/v1/albums/52zcKFagA0FwPArP7g94sH',
#      'id': '52zcKFagA0FwPArP7g94sH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f22638191ebb03203ecd9e636aa9e6910010e977',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ebfabec50068e8ef2c3e5eb831779d5828301932',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/450df66dc4b2383c3145e6e6220c9a570c6acf4b',
#        'width': 64}],
#      'name': 'Was wollen wir trinken',
#      'release_date': '2012-06-08',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:52zcKFagA0FwPArP7g94sH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KpgeSLtjj0txr6drzaedu'},
#       'href': 'https://api.spotify.com/v1/artists/4KpgeSLtjj0txr6drzaedu',
#       'id': '4KpgeSLtjj0txr6drzaedu',
#       'name': 'Basslovers United',
#       'type': 'artist',
#       'uri': 'spotify:artist:4KpgeSLtjj0txr6drzaedu'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 195362,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEHK91260801'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5KywwmlnfTZ4YymZy9Z82k'},
#     'href': 'https://api.spotify.com/v1/tracks/5KywwmlnfTZ4YymZy9Z82k',
#     'id': '5KywwmlnfTZ4YymZy9Z82k',
#     'is_local': False,
#     'name': 'Was wollen wir trinken - Radio Edit',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/026eb1168f3646e2ac0b9a4927bc6d01593fbcec?cid=71f8b6e1b36740a8acda7e15c5e1d73d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5KywwmlnfTZ4YymZy9Z82k'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Basslovers+United&type=track&market=US&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 373}}

# %%
artist_name = results_t['tracks']['items'][0]['album']['artists'][0]['name']
artist_name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-c5483ec966ce> in <module>()
# ----> 1 artist_name = results_t['tracks']['items'][0]['album']['artists'][0]['name']
#       2 artist_name
#
# IndexError: list index out of range
